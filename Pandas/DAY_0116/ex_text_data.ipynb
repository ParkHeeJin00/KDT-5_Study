# %% [markdown]
# ## [ 텍스트 데이터 처리 ]
# - 다양한 형태의 텍스트 데이터를 정리하기 위한 방법들
#  - Series에 str 속성을 활용
#  - 사용방법 : Series객체.str.메서드()

# %% [markdown]
# - 문자열 관련 메서드들 살펴보기
# (1) 공백 제거 관련 메서드 => strip() lstrip() rstrip()

# %%
msg = "   Merry Christmas     "

# %%
len(msg)
# Out:
# 23

# %%
msg1,msg2,msg3 = msg.strip(), msg.lstrip(), msg.rstrip()

# %%
len(msg1),len(msg2),len(msg3)
# Out:
# (15, 20, 18)

# %% [markdown]
# <hr>
# (1) 모듈 로딩
# <hr>

# %%
import pandas as pd

# %% [markdown]
# (2) 데이터 준비<hr>

# %%
file = "../../DATA/chicago_food_inspections.csv"

# %% [markdown]
# (3) 데이터 저장<hr>

# %%
chicagoDF = pd.read_csv(file)

# %% [markdown]
# (4) 데이터 확인 <hr>

# %%
chicagoDF.head()
# Out:
#                           Name             Risk
# 0   MARRIOT MARQUIS CHICAGO       Risk 1 (High)
# 1                  JETS PIZZA   Risk 2 (Medium)
# 2                   ROOM 1520      Risk 3 (Low)
# 3    MARRIOT MARQUIS CHICAGO      Risk 1 (High)
# 4                CHARTWELLS       Risk 1 (High)

# %% [markdown]
# - [문제] Name 컬럼에서 공백 제거 처리

# %%
chicagoDF['Name'] = chicagoDF['Name'].str.strip()   ## 저장안하면 적용 X

# %% [markdown]
# - [문제] Risk 컬럼에서 문자열 나누기 => Risk 숫자 ==> Risk와 숫자 분리

# %%
chicagoDF['Risk'].isna().sum(), chicagoDF.isna().sum()
# Out:
# (66,
#  Name     0
#  Risk    66
#  dtype: int64)

# %%
# 기본 => 행 방향, 행 내에 한개라도 NaN이 있으면 삭제
chicagoDF.dropna().shape
# Out:
# (153744, 2)

# %%
# Risk 컬럼이 NaN인 행 삭제 => subset 파라미터 적용
chicagoDF.dropna(subset=['Risk']).shape   ## subset = ['Name'] => 하나도 안지워짐 / Name에 NaN없음
# Out:
# (153744, 2)

# %%
# 원소의 데이터 값이 'all' => 'Risk 4(Extreme)' 변경
chicagoDF['Risk'].replace('all','Risk 4(Extreme)')
# Out:
# 0           Risk 1 (High)
# 1         Risk 2 (Medium)
# 2            Risk 3 (Low)
# 3           Risk 1 (High)
# 4           Risk 1 (High)
#                ...
# 153805      Risk 1 (High)
# 153806    Risk 2 (Medium)
# 153807      Risk 1 (High)
# 153808      Risk 1 (High)
# 153809      Risk 1 (High)
# Name: Risk, Length: 153810, dtype: object

# %%
chicagoDF['Risk'].str[5:6]   # type : serise
# = chicagoDF['Risk'].str.silce(5,6)
