# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# - 1번

# %%
nfl = pd.read_csv('../DATA/nfl.csv',parse_dates=['Birthday'])

# %% [markdown]
# - 2번

# %%
# 1
nfl.set_index('Name')
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
# 2
nfl = pd.read_csv('../DATA/nfl.csv',index_col='Name',parse_dates=['Birthday'])

# %% [markdown]
# - 3번

# %%
nfl.value_counts('Team')
# Out:
# Team
# New York Jets           58
# Washington Redskins     56
# Kansas City Chiefs      56
# San Francisco 49Ers     55
# New Orleans Saints      55
# Denver Broncos          54
# Minnesota Vikings       54
# Los Angeles Chargers    54
# Dallas Cowboys          53
# Chicago Bears           53
# Detroit Lions           53
# Seattle Seahawks        53
# Buffalo Bills           53
# Atlanta Falcons         53
# Houston Texans          52
# Philadelphia Eagles     52
# Los Angeles Rams        52
# New York Giants         52
# Oakland Raiders         51
# Arizona Cardinals       51
# Cincinnati Bengals      51
# Green Bay Packers       51
# Jacksonville Jaguars    50
# Cleveland Browns        49
# Carolina Panthers       49
# Miami Dolphins          49
# Indianapolis Colts      49
# New England Patriots    49
# Baltimore Ravens        48
# Pittsburgh Steelers     47
# Tampa Bay Buccaneers    47
# Tennessee Titans        46
# Name: count, dtype: int64

# %%
nfl['Team'].value_counts()
# Out:
# Team
# New York Jets           58
# Kansas City Chiefs      56
# Washington Redskins     56
# New Orleans Saints      55
# San Francisco 49Ers     55
# Denver Broncos          54
# Minnesota Vikings       54
# Los Angeles Chargers    54
# Seattle Seahawks        53
# Dallas Cowboys          53
# Buffalo Bills           53
# Atlanta Falcons         53
# Detroit Lions           53
# Chicago Bears           53
# Los Angeles Rams        52
# New York Giants         52
# Philadelphia Eagles     52
# Houston Texans          52
# Arizona Cardinals       51
# Cincinnati Bengals      51
# Green Bay Packers       51
# Oakland Raiders         51
# Jacksonville Jaguars    50
# Cleveland Browns        49
# Miami Dolphins          49
# Indianapolis Colts      49
# Carolina Panthers       49
# New England Patriots    49
# Baltimore Ravens        48
# Pittsburgh Steelers     47
# Tampa Bay Buccaneers    47
# Tennessee Titans        46
# Name: count, dtype: int64

# %% [markdown]
# - 4번

# %%
nfl.sort_values('Salary',ascending=False).head()    # head() 기본값 : n = 5
# Out:
#                                  Team Position   Birthday    Salary
# Name
# Kirk Cousins        Minnesota Vikings       QB 1988-08-19  27500000
# Jameis Winston   Tampa Bay Buccaneers       QB 1994-01-06  20922000
# Marcus Mariota       Tennessee Titans       QB 1993-10-30  20922000
# Derek Carr            Oakland Raiders       QB 1991-03-28  19900000
# Jimmy Garoppolo   San Francisco 49Ers       QB 1991-11-02  17200000

# %%
nfl.sort_values(['Team','Salary'],ascending=[True,False])
# Out:
#                                    Team Position   Birthday    Salary
# Name
# Chandler Jones        Arizona Cardinals      OLB 1990-02-27  16500000
# Patrick Peterson      Arizona Cardinals       CB 1990-07-11  11000000
# Larry Fitzgerald      Arizona Cardinals       WR 1983-08-31  11000000
# David Johnson         Arizona Cardinals       RB 1991-12-16   5700000
# Justin Pugh           Arizona Cardinals        G 1990-08-15   5000000
# ...                                 ...      ...        ...       ...
# Ross Pierschbacher  Washington Redskins        C 1995-05-05    495000
# Kelvin Harmon       Washington Redskins       WR 1996-12-15    495000
# Wes Martin          Washington Redskins        G 1996-05-09    495000
# Jimmy Moreland      Washington Redskins       CB 1995-08-26    495000
# Jeremy Reaves       Washington Redskins       SS 1996-08-29    495000
#
# [1655 rows x 4 columns]

# %% [markdown]
# - 5번

# %%
nfl = nfl.sort_values('Birthday')

# %%
nfl = nfl.reset_index().set_index('Team')
nfl
# Out:
#                       index            Name Position   Birthday    Salary
# Team
# New England Patriots    776       Tom Brady       QB 1977-08-03  14000000
# New Orleans Saints      345      Drew Brees       QB 1979-01-15   1400000
# Philadelphia Eagles    1271     Josh McCown       QB 1979-07-04   2000000
# New York Giants         145     Eli Manning       QB 1981-01-03  11500000
# Atlanta Falcons         119     Matt Schaub       QB 1981-06-25   1030000
# ...                     ...             ...      ...        ...       ...
# Arizona Cardinals       337  Jalen Thompson       SS 1998-07-18    495000
# Pittsburgh Steelers     685      Devin Bush      ILB 1998-07-18    495000
# Seattle Seahawks       1467    Travis Homer       RB 1998-08-07    495000
# Minnesota Vikings      1574   Irv Smith Jr.       TE 1998-08-09   1447500
# Detroit Lions          1217     Will Harris       SS 1998-12-19    495000
#
# [1655 rows x 5 columns]

# %%
nfl.loc['New York Jets']
# Out:
#                index                Name Position   Birthday   Salary
# Team
# New York Jets    888          Ryan Kalil        C 1985-03-29  2400000
# New York Jets   1448      Steve McLendon       NT 1986-01-03  1500000
# New York Jets   1272    Albert McClellan      ILB 1986-06-04   805000
# New York Jets    498    Demaryius Thomas       WR 1987-10-25  1200000
# New York Jets   1237        Bilal Powell       RB 1988-10-04   930000
# New York Jets   1560        Rontez Miles       SS 1988-11-25  1907000
# New York Jets   1060         Tom Compton        G 1989-05-10  1410000
# New York Jets    373        Josh Bellamy       WR 1989-05-18   930000
# New York Jets   1597      Kelvin Beachum       OT 1989-06-08  8000000
# New York Jets    705    Trumaine Johnson       CB 1990-01-01  8000000
# New York Jets    730       Paul Worrilow      ILB 1990-05-01   805000
# New York Jets    427         David Fales       QB 1990-10-04   805000
# ...

# %%
nfl.loc['New York Jets'].head(1)
# Out:
#                index        Name Position   Birthday   Salary
# Team
# New York Jets    888  Ryan Kalil        C 1985-03-29  2400000
