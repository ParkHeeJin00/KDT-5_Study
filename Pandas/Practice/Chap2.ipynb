# %%
import pandas as pd
import numpy as np

# %%
number = pd.Series([1,2,3,np.nan,4,5])

# %%
number.sum(min_count=4)    
# 계산을 하는데 필요한 유효한 데이터의 개수 지정 -> 결측치 제외하고도 4개의 데이터를 가지면 연산 가능
# Out:
# 15.0

# %% [markdown]
# - 코딩챌린지

# %%
import pandas as pd
import numpy as np

superheroes = [
    "Batman",
    "Superman",
    "Spider-Man",
    "Iron Man",
    "Captain America",
    "Wonder Woman"
]

strength_levels = (100,120,90,95,110,120)

# %%
sr = pd.Series(superheroes)
sr
# Out:
# array(['Batman', 'Superman', 'Spider-Man', 'Iron Man', 'Captain America',
#        'Wonder Woman'], dtype=object)

# %%
sr2 = pd.Series(strength_levels)
sr2
# Out:
# 0    100
# 1    120
# 2     90
# 3     95
# 4    110
# 5    120
# dtype: int64

# %%
heroes = pd.Series(strength_levels, index=superheroes)
heroes
# Out:
# Batman             100
# Superman           120
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.head(2)
# Out:
# Batman      100
# Superman    120
# dtype: int64

# %%
heroes.tail(4)
# Out:
# Spider-Man          90
# Iron Man            95
# Captain America    110
# Wonder Woman       120
# dtype: int64

# %%
heroes.nunique()
# Out:
# 5

# %%
heroes.mean()
# Out:
# 105.83333333333333

# %%
heroes.max()
# Out:
# 120

# %%
heroes.min()
# Out:
# 90

# %%
heroes * 2
# Out:
# Batman             200
# Superman           240
# Spider-Man         180
# Iron Man           190
# Captain America    220
# Wonder Woman       240
# dtype: int64

# %%
dict(heroes)
# Out:
# {'Batman': 100,
#  'Superman': 120,
#  'Spider-Man': 90,
#  'Iron Man': 95,
#  'Captain America': 110,
#  'Wonder Woman': 120}
